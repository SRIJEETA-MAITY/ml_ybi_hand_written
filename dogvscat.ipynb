# %% [markdown]
# <a href="https://colab.research.google.com/github/SRIJEETA-MAITY/ml_ybi_hand_written/blob/main/dogvscat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# extracting dataset from kaggel
# !pip install kaggle

# %%
# configuring the path of kaggel.json fil
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# importing dog vs cat dataset
# kaggle api
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#  99% 805M/812M [00:09<00:00, 34.8MB/s]
# 100% 812M/812M [00:10<00:00, 84.3MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  kaggle.json  sample_data

# %%
from zipfile import ZipFile
file_name = "dogs-vs-cats.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
# extracting training data
from zipfile import ZipFile
traindataset = "train.zip"

with ZipFile(traindataset, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import os
# counting the number of filed from train folder
path,dirs,files=next(os.walk('train'))
file_count=len(files)
print('nuber of images :', file_count)
# Out:
# nuber of images : 25000

# %%
# printing the name of images
file_names=os.listdir('train')
print(file_names)
# Out:
# ['cat.2112.jpg', 'dog.11559.jpg', 'cat.8209.jpg', 'dog.9913.jpg', 'cat.152.jpg', 'cat.2571.jpg', 'dog.656.jpg', 'dog.5665.jpg', 'cat.10207.jpg', 'cat.7123.jpg', 'cat.3575.jpg', 'cat.10625.jpg', 'cat.1472.jpg', 'dog.275.jpg', 'cat.5702.jpg', 'dog.3973.jpg', 'cat.8207.jpg', 'cat.4934.jpg', 'cat.2767.jpg', 'dog.7790.jpg', 'dog.10434.jpg', 'cat.11014.jpg', 'cat.9485.jpg', 'dog.10929.jpg', 'dog.6554.jpg', 'dog.11215.jpg', 'dog.3259.jpg', 'cat.6200.jpg', 'cat.2443.jpg', 'dog.10342.jpg', 'dog.4864.jpg', 'cat.5698.jpg', 'dog.3268.jpg', 'cat.6910.jpg', 'dog.4744.jpg', 'dog.11861.jpg', 'cat.4278.jpg', 'dog.3186.jpg', 'cat.376.jpg', 'cat.7097.jpg', 'cat.7968.jpg', 'cat.612.jpg', 'dog.12450.jpg', 'dog.5180.jpg', 'dog.7140.jpg', 'dog.9044.jpg', 'cat.9830.jpg', 'dog.5788.jpg', 'dog.9257.jpg', 'cat.5575.jpg', 'cat.6419.jpg', 'dog.11163.jpg', 'dog.7439.jpg', 'cat.10001.jpg', 'dog.3249.jpg', 'dog.6834.jpg', 'dog.1481.jpg', 'cat.7115.jpg', 'cat.1910.jpg', 'dog.4015.jpg', 'dog.5845.jpg', 'cat.5980.jpg'
# ...

# %% [markdown]
# importing important library

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow
import cv2

# %%
# displaying images of dogs and cats
#display dog
img=mpimg.imread('/content/train/dog.3817.jpg')
imgplot=plt.imshow(img)
plt.show()

# %%
# diplaying image of cat
catimg=mpimg.imread('/content/train/cat.10001.jpg')
imgplot=plt.imshow(catimg)
plt.show()

# %%
file_names=os.listdir('train')
for i in range(5):
  name=file_names[i]
  print(name[0:3])
# Out:
# cat
# dog
# cat
# dog
# cat

# %% [markdown]
# to count the number of dog image and cat image

# %%
file_names=os.listdir('train')
dog_count=0
cat_count=0

for img_file in file_names:
  name=img_file[0:3]

  if name=='dog':
    dog_count+=1
  else:
    cat_count+=1

print('dog count :',dog_count)
print('cat count :',cat_count)
# Out:
# dog count : 12500
# cat count : 12500

# %% [markdown]
# resizing all images
